# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.rename(columns={'sex': 'Gender'}, inplace=True)

# %%
tips.head()
# Out:
#    total_bill   tip  Gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   Gender      244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.tail(10)
# Out:
#      total_bill   tip  Gender smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.count()
# Out:
# total_bill    244
# tip           244
# Gender        244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %% [markdown]
# # Shapes and Data Types

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# Gender        category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
b
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Data Cleaning

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# Gender        0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.duplicated().sum()
# Out:
# 1

# %%
tips.drop_duplicates()
# Out:
#      total_bill   tip  Gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Numerical

# %%
sns.histplot(tips['total_bill'])
plt.title('Distribution of Total Bill')
# Out:
# Text(0.5, 1.0, 'Distribution of Total Bill')

# %%
sns.histplot(tips['tip'])
plt.title('Distribution of Tips')
# Out:
# Text(0.5, 1.0, 'Distribution of Tips')

# %%
sns.histplot(tips['size'])
plt.title('Distribution of Size')
# Out:
# Text(0.5, 1.0, 'Distribution of Size')

# %%
sns.boxplot(x=tips['tip'])
plt.title('Boxplot of Tips')   #it shows the mean value distribution to find the outliers
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips')

# %%
sns.boxplot(x=tips['size'])
plt.title('Boxplot of Size')   #it shows the mean value distribution
# Out:
# Text(0.5, 1.0, 'Boxplot of Size')

# %%
sns.boxplot(x=tips['total_bill'])
plt.title('Boxplot of Total Bill')
# Out:
# Text(0.5, 1.0, 'Boxplot of Total Bill')

# %% [markdown]
# ## Categorical Colums

# %%
sns.countplot(x='day', data=tips)
plt.title('Categorical Observation of Day')
# Out:
# Text(0.5, 1.0, 'Categorical Observation of Day')

# %%
sns.countplot(x='Gender', data=tips)
plt.title('Categorical Observation of Gender')
# Out:
# Text(0.5, 1.0, 'Categorical Observation of Gender')

# %%
sns.countplot(x='time', data=tips)
plt.title('Categorical Observation of TIme')
# Out:
# Text(0.5, 1.0, 'Categorical Observation of TIme')

# %%
sns.countplot(x='smoker', data=tips)
plt.title('Categorical Observation of Smoker')
# Out:
# Text(0.5, 1.0, 'Categorical Observation of Smoker')

# %%
ab=np.array([18,19,17,20, 180]) #this example for detect outliers like 180 is outliers

# %%
ab.mean() #if we don't remove 180 then it will give incorrect result.
# Out:
# 50.8

# %% [markdown]
# ### Bivariate Analysis

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   Gender      244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### Numerical-numerical Relationship

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='tip', palette='coolwarm')
plt.title('Total Bill Vs Tips')
plt.show()

# %%
sns.scatterplot(x='size', y='tip', data=tips, hue='tip', palette='coolwarm')
plt.title('Total Size Vs Tips')
plt.show()

# %%
sns.scatterplot(x='total_bill', y='size', data=tips, hue='size', palette='coolwarm')
plt.title('Total Bill Vs Size')
plt.show()

# %%
cor=tips.corr(numeric_only=True)

# %%
sns.heatmap(cor, annot=True, cmap='coolwarm')
plt.title('Correlation between numerical values')
# Out:
# Text(0.5, 1.0, 'Correlation between numerical values')

# %% [markdown]
# ## Numerical-categorial Relationship

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'Gender', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxplot(x='Gender', y='tip', data=tips)
plt.title('Boxplot of Gender Vs Tips')   #it shows the mean value distribution
# Out:
# Text(0.5, 1.0, 'Boxplot of Gender Vs Tips')

# %%
sns.boxplot(x='smoker', y='tip', data=tips)
plt.title('Boxplot of Smoker Vs Tips')   #it shows the mean value distribution
# Out:
# Text(0.5, 1.0, 'Boxplot of Smoker Vs Tips')

# %%
sns.violinplot(x='smoker', y='tip', data=tips)
plt.title('violinplot of Smoker Vs Tips')
# Out:
# Text(0.5, 1.0, 'violinplot of Smoker Vs Tips')

# %% [markdown]
# ## Categorical - Categorical Relationship

# %%
sns.countplot(x='smoker', hue='Gender', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day', hue='time', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(tips, hue='Gender') 
plt.title('pairplots')
# Out:
# Text(0.5, 1.0, 'pairplots')

# %% [markdown]
# ### Grouping and Aggregation

# %%
tips.groupby('Gender')['tip'].mean()
# Out:
# Gender
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
tips.groupby('day').agg({'total_bill':'mean', 'tip':'mean'}) #aggrigate fucntion is used to get the mean value of multiple categories
# Out:
#       total_bill       tip
# day
# Thur   17.682742  2.771452
# Fri    17.151579  2.734737
# Sat    20.441379  2.993103
# Sun    21.410000  3.255132

# %%
tips.groupby(['Gender','day'])['tip'].mean() #To find the tips based on the Gender and Day
# Out:
# Gender  day
# Male    Thur    2.980333
#         Fri     2.693000
#         Sat     3.083898
#         Sun     3.220345
# Female  Thur    2.575625
#         Fri     2.781111
#         Sat     2.801786
#         Sun     3.367222
# Name: tip, dtype: float64

# %% [markdown]
# ## Feature Engineering

# %%
tips['tip_percent']=(tips['tip']/tips['total_bill'])*100

# %%
tips.tail()
# Out:
#      total_bill   tip  Gender smoker   day    time  size  tip_percent
# 239       29.03  5.92    Male     No   Sat  Dinner     3    20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2     9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2    15.974441

# %%
sns.histplot(tips['tip_percent'],kde=True) #kde: Kernel Density Estimation
# Out:
# <Axes: xlabel='tip_percent', ylabel='Count'>

# %%
tips['tip_percent'].describe()
# Out:
# count    244.000000
# mean      16.080258
# std        6.107220
# min        3.563814
# 25%       12.912736
# 50%       15.476977
# 75%       19.147549
# max       71.034483
# Name: tip_percent, dtype: float64

# %% [markdown]
# ### Handling Outliers

# %%
tips_adjusted=tips[tips['tip_percent']<40]   #remove outliers using domain knowledge

# %%
tips_adjusted['tip_percent'].describe()
# Out:
# count    242.000000
# mean      15.747446
# std        4.716886
# min        3.563814
# 25%       12.853825
# 50%       15.408357
# 75%       18.995586
# max       32.573290
# Name: tip_percent, dtype: float64

# %%
sns.boxplot(x=tips['tip_percent'])
plt.title('Boxplot of Tips Percent')   #it shows the mean value distribution
# Out:
# Text(0.5, 1.0, 'Boxplot of Tip Percent')

# %% [markdown]
# ### Remove outliter using interquartile

# %%
Q1=tips['total_bill'].quantile(0.25)
Q3=tips['total_bill'].quantile(0.75)

# %%
Q1
# Out:
# 13.3475

# %%
Q3
# Out:
# 24.127499999999998

# %% [markdown]
# #### Calculating IQR (Intern Quartile Rang)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 10.779999999999998

# %% [markdown]
# ### Boundaries Defining

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
lower_bound
# Out:
# -2.8224999999999945

# %%
upper_bound
# Out:
# 40.29749999999999

# %%
tips_clean=tips[(tips['total_bill']>=lower_bound) & (tips['total_bill']<=upper_bound)]

# %%
tips_clean['total_bill'].describe()
# Out:
# count    235.000000
# mean      18.798681
# std        7.438468
# min        3.070000
# 25%       13.215000
# 50%       17.460000
# 75%       23.135000
# max       40.170000
# Name: total_bill, dtype: float64

# %%
sns.boxplot(x='day', y='tip', data=tips)
plt.title('Boxplot of Day Vs Tips')   #it shows the mean value distribution
# Out:
# Text(0.5, 1.0, 'Boxplot of Day Vs Tips')

# %%
sns.boxplot(x='smoker', y='tip', data=tips)
plt.title('Boxplot of Smoker Vs Tips')
# Out:
# Text(0.5, 1.0, 'Boxplot of Smoker Vs Tips')
