# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sns.load_dataset("flights")
print(flights.head())
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
flights.shape
# Out:
# (144, 3)

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
flights.drop_duplicates()
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.histplot(flights['passengers'])
plt.title('Distribution of Passengers')
# Out:
# Text(0.5, 1.0, 'Distribution of Passengers')

# %%
sns.boxplot(x='month', y='passengers', data=flights)
plt.title('Boxplot of Month Vs Passengers')
# Out:
# Text(0.5, 1.0, 'Boxplot of Month Vs Passengers')

# %%
# Group by year and sum the passengers
total_passengers_per_year = flights.groupby('year')['passengers'].sum().reset_index()

# Display the result
print(total_passengers_per_year)
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
total_passenger = flights.groupby('year')['passengers'].sum().reset_index()

# %%
sns.barplot(x='year', y='passengers', data=total_passenger, palette='coolwarm')
plt.title('Total Passengers per Year')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Year')

# %%
# Group by year and sum the passengers
total_passengers_per_month = flights.groupby('month')['passengers'].sum().reset_index()

# Display the result
print(total_passengers_per_month)
# Out:
#    month  passengers
# 0    Jan        2901
# 1    Feb        2820
# 2    Mar        3242
# 3    Apr        3205
# 4    May        3262
# 5    Jun        3740
# 6    Jul        4216
# 7    Aug        4213
# 8    Sep        3629
# 9    Oct        3199
# 10   Nov        2794
# 11   Dec        3142

# %%
total_passenger_m = flights.groupby('month')['passengers'].sum().reset_index()

# %%
sns.barplot(x='month', y='passengers', data=total_passenger_m, palette='viridis')
plt.title('Total Passengers per Month')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Month')

# %%
sns.lineplot(x='month', y='passengers', data=total_passenger_m, marker='o', color='b')
plt.title('Total Passengers per Year')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Year')
