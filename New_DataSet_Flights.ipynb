# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sns.load_dataset("flights")
print(flights.head())
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
flights.shape
# Out:
# (144, 3)

# %%
flights.head(13)
# Out:
#     year month  passengers
# 0   1949   Jan         112
# 1   1949   Feb         118
# 2   1949   Mar         132
# 3   1949   Apr         129
# 4   1949   May         121
# 5   1949   Jun         135
# 6   1949   Jul         148
# 7   1949   Aug         148
# 8   1949   Sep         136
# 9   1949   Oct         119
# 10  1949   Nov         104
# 11  1949   Dec         118
# 12  1950   Jan         115

# %%
flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
flights.drop_duplicates()
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.boxplot(x='month', y='passengers', data=flights)
plt.title('Boxplot of Month Vs Passengers')
# Out:
# Text(0.5, 1.0, 'Boxplot of Month Vs Passengers')

# %%
# Group by year and sum the passengers
total_passengers_per_year = flights.groupby('year')['passengers'].sum().reset_index()

# Display the result
print(total_passengers_per_year)
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
total_passenger = flights.groupby('year')['passengers'].sum().reset_index()

# %%
sns.barplot(x='year', y='passengers', data=total_passenger, palette='coolwarm')
plt.title('Total Passengers per Year')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Year')

# %%
#sns.scatterplot(x='year', y='passengers', data=total_passenger)
#plt.title('Total Passengers per Year')
#plt.show()

# %%
total_passenger_m = flights.groupby('month')['passengers'].sum().reset_index()
print(total_passenger_m)
# Out:
#    month  passengers
# 0    Jan        2901
# 1    Feb        2820
# 2    Mar        3242
# 3    Apr        3205
# 4    May        3262
# 5    Jun        3740
# 6    Jul        4216
# 7    Aug        4213
# 8    Sep        3629
# 9    Oct        3199
# 10   Nov        2794
# 11   Dec        3142

# %%
sns.barplot(x='month', y='passengers', data=total_passenger_m, palette='viridis')
plt.title('Total Passengers per Month')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Month')

# %%
sns.lineplot(x='month', y='passengers', data=total_passenger_m, marker='o', color='b')
plt.title('Total Passengers per Year')
# Out:
# Text(0.5, 1.0, 'Total Passengers per Year')

# %%
sns.lineplot(x='month', y='passengers', hue='year', data=flights, palette='tab10')
plt.title('Monthly Passengers for Each Year')
# Out:
# Text(0.5, 1.0, 'Monthly Passengers for Each Year')

# %%
year_data = flights[flights['year'] == 1960]
sns.lineplot(x='month', y='passengers', data=year_data, marker='o', color='b')
plt.title('Monthly Passengers in 1960')
# Out:
# Text(0.5, 1.0, 'Monthly Passengers in 1960')

# %%
year_data = flights[flights['year'] == 1955]
sns.barplot(x='month', y='passengers', data=year_data, palette='viridis')
plt.title('Monthly Passengers in 1955')
# Out:
# Text(0.5, 1.0, 'Monthly Passengers in 1955')

# %%
cor=flights.corr(numeric_only=True)

# %%
sns.heatmap(cor, annot=True, cmap='coolwarm')
plt.title('Correlation between numerical values')
# Out:
# Text(0.5, 1.0, 'Correlation between numerical values')
